# %% [markdown]
# ## 1. 클래스 정의하기
#
# - 클래스: 객체를 만들기 위한 설계도(자동차 설계도)
# - 객체: 클래스에 의해 실제 생성된 객체(자동차)
# - 메소드: 클래스 안에 정의된 함수
# - 생성자: 객체가 생성될때 호출되는 메소드. 객체의 초기 상태를 설정하거나 필요한 작업 수행

# %%
class Calculator:
    def __init__(self): #생성자
        self.result = 0  # 객체의 초기 상태를 설정

    def add(self, num):
        self.result += num  # result 값을 업데이트
        return self.result

cal1 = Calculator()  # __init__이 호출되어 cal1.result = 0으로 초기화
cal2 = Calculator()  # __init__이 호출되어 cal2.result = 0으로 초기화

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class FourCal:
     def __init__(self, first, second):
         self.first = first
         self.second = second
     def setdata(self, first, second):
         self.first = first
         self.second = second
     def add(self):
         result = self.first + self.second
         return result
     def mul(self):
         result = self.first * self.second
         return result
     def sub(self):
         result = self.first - self.second
         return result
     def div(self):
         result = self.first / self.second
         return result

a = FourCal(4, 2)
print(a.first)
print(a.second)

print(a.add())
print(a.div())
# Out:
# 4
# 2
# 6
# 2.0

# %% [markdown]
# ## 2. 클래스의 상속
# 부모 클래스의 기능을 상속받아 사용 가능

# %%
class MoreFourCal(FourCal):  # FourCald에 정의된 메소드 사용 가능
    def pow(self):
        result = self.first ** self.second
        return result

b = MoreFourCal(4, 2)
print(b.add())
print(b.div())
print(b.pow())
# Out:
# 6
# 2.0
# 16

# %% [markdown]
# ## 3. 메서드 오버라이딩
# 부모 클래스의 메소드를 동일한 이름으로 다시 만드는 것

# %%
a = FourCal(4, 0)
a.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 a = FourCal(4, 0)
# ----> 2 a.div()
#
# Cell In[13], line 18, in FourCal.div(self)
#      17 def div(self):
# ---> 18     result = self.first / self.second
#      19     return result
#
# ZeroDivisionError: division by zero

# %%
#부모 클래스의 메소드를 동일한 이름으로 다시 만든다

class SafeFourCal(FourCal):
     def div(self):
         if self.second == 0:  # 나누는 값이 0인 경우 0을 리턴하도록 수정
             return 0
         else:
             return self.first / self.second


a = SafeFourCal(4, 0)
a.div()
# Out:
# 0

# %% [markdown]
# ## 4. 클래스 변수
# 클래스에 또 다른 이름 지정가능(자주 사용하진 X)

# %%
class Family:
     lastname = "haseo"

Family.lastname
# Out:
# 'haseo'

# %%
a = Family()
b = Family()
print(a.lastname)
print(b.lastname)
# Out:
# haseo
# haseo

# %%
Family.lastname = "jisu"
Family.lastname
# Out:
# 'jisu'
